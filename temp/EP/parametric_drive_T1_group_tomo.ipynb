# %% [markdown]
# # Parametric Drive T1 Analysis
#
# This notebook reads and visualizes the parametric drive T1 data from the .h5 file.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Set plotting style
# plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (12, 8)

# %%
from qcat.parser.qm_reader import load_xarray_h5, repetition_data
from qcat.utilities.simple_visualization import plot_2d_colormap_from_h5

# %%
# Define the root folder path
root_folder = r"/Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180"  # Modify this path as needed

print(f"Listing all folders under: {root_folder}")
print("-" * 50)

if os.path.exists(root_folder):
    try:
        # Method 1: List immediate subdirectories only
        folders = [item for item in os.listdir(root_folder) 
                  if os.path.isdir(os.path.join(root_folder, item))]
        
        if folders:
            print("Immediate subdirectories and file status:")
            folders_with_both = []
            folders_missing_files = []
            
            for folder in sorted(folders):
                folder_path = os.path.join(root_folder, folder)
                h5_file_path = os.path.join(folder_path, "ds_raw.h5")
                node_json_path = os.path.join(folder_path, "node.json")
                
                h5_exists = os.path.exists(h5_file_path)
                json_exists = os.path.exists(node_json_path)
                
                if h5_exists and json_exists:
                    print(f"  📁 {folder} ✅ (both ds_raw.h5 and node.json found)")
                    folders_with_both.append(folder)
                else:
                    status_parts = []
                    if not h5_exists:
                        status_parts.append("ds_raw.h5 missing")
                    if not json_exists:
                        status_parts.append("node.json missing")
                    print(f"  📁 {folder} ❌ ({', '.join(status_parts)})")
                    folders_missing_files.append(folder)
            
            # Summary
            print(f"\nSummary:")
            print(f"  Total folders: {len(folders)}")
            print(f"  Folders with both files: {len(folders_with_both)}")
            print(f"  Folders missing files: {len(folders_missing_files)}")
            
            if folders_with_both:
                print(f"\n✅ Folders ready for analysis (both files present):")
                for folder in folders_with_both:
                    print(f"    - {folder}")
                    
            if folders_missing_files:
                print(f"\n❌ Folders with missing files:")
                for folder in folders_missing_files:
                    folder_path = os.path.join(root_folder, folder)
                    h5_file_path = os.path.join(folder_path, "ds_raw.h5")
                    node_json_path = os.path.join(folder_path, "node.json")
                    
                    h5_exists = os.path.exists(h5_file_path)
                    json_exists = os.path.exists(node_json_path)
                    
                    status_parts = []
                    if not h5_exists:
                        status_parts.append("ds_raw.h5")
                    if not json_exists:
                        status_parts.append("node.json")
                    print(f"    - {folder} (missing: {', '.join(status_parts)})")
        else:
            print("No subdirectories found.")
            
        print(f"\nFound {len(folders)} folders")
        
    except PermissionError:
        print(f"Permission denied accessing: {root_folder}")
    except Exception as e:
        print(f"Error accessing folder: {e}")
else:
    print(f"Root folder does not exist: {root_folder}")
    print("Please check the path and try again.")
# Out:
# Listing all folders under: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180
# --------------------------------------------------
# Immediate subdirectories and file status:
#   📁 #1508_LCH_qubit_parametric_drive_time_tomo_0_224304 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1509_LCH_qubit_parametric_drive_time_tomo_1_225238 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1510_LCH_qubit_parametric_drive_time_tomo_2_230213 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1511_LCH_qubit_parametric_drive_time_tomo_3_231147 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1512_LCH_qubit_parametric_drive_time_tomo_4_232122 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1513_LCH_qubit_parametric_drive_time_tomo_5_233056 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1514_LCH_qubit_parametric_drive_time_tomo_6_234031 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1515_LCH_qubit_parametric_drive_time_tomo_7_235006 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1516_LCH_qubit_parametric_drive_time_tomo_8_235940 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1517_LCH_qubit_parametric_drive_time_tomo_9_000914 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1518_LCH_qubit_parametric_drive_time_tomo_10_001849 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1519_LCH_qubit_parametric_drive_time_tomo_11_002823 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1520_LCH_qubit_parametric_drive_time_tomo_12_003758 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1521_LCH_qubit_parametric_drive_time_tomo_13_004732 ✅ (both ds_raw.h5 and node.json found)
#   📁 #1522_LCH_qubit_parametric_drive_time_tomo_14_005707 ✅ (both ds_raw.h5 and node.json found)
#
# Summary:
#   Total folders: 15
#   Folders with both files: 15
#   Folders missing files: 0
#
# ✅ Folders ready for analysis (both files present):
#     - #1508_LCH_qubit_parametric_drive_time_tomo_0_224304
#     - #1509_LCH_qubit_parametric_drive_time_tomo_1_225238
#     - #1510_LCH_qubit_parametric_drive_time_tomo_2_230213
#     - #1511_LCH_qubit_parametric_drive_time_tomo_3_231147
#     - #1512_LCH_qubit_parametric_drive_time_tomo_4_232122
#     - #1513_LCH_qubit_parametric_drive_time_tomo_5_233056
#     - #1514_LCH_qubit_parametric_drive_time_tomo_6_234031
#     - #1515_LCH_qubit_parametric_drive_time_tomo_7_235006
#     - #1516_LCH_qubit_parametric_drive_time_tomo_8_235940
#     - #1517_LCH_qubit_parametric_drive_time_tomo_9_000914
#     - #1518_LCH_qubit_parametric_drive_time_tomo_10_001849
#     - #1519_LCH_qubit_parametric_drive_time_tomo_11_002823
#     - #1520_LCH_qubit_parametric_drive_time_tomo_12_003758
#     - #1521_LCH_qubit_parametric_drive_time_tomo_13_004732
#     - #1522_LCH_qubit_parametric_drive_time_tomo_14_005707
#
# Found 15 folders

# %%
# Extract data from folders with both ds_raw.h5 and node.json files
import json
print("Extracting data from verified folders...")
print("=" * 60)

# Define analysis parameters (similar to parametric_drive_T1.ipynb cell 7)
target_times = [400,500,600,700,800,900,1000,1100,1200,1300,1400]  # Time points for averaging (in ns)

# Results storage
results = []

# Process each folder with both required files
if 'folders_with_both' in locals() and folders_with_both:
    for folder in folders_with_both:
        try:
            print(f"\nProcessing: {folder}")
            h5_file_path = os.path.join(root_folder, folder, "ds_raw.h5")
            node_json_path = os.path.join(root_folder, folder, "node.json")
            
            # Extract driving_amp_ratio from node.json (both files verified to exist)
            try:
                with open(node_json_path, 'r') as f:
                    node_data = json.load(f)
                driving_amp_ratio = node_data.get('data', {}).get('parameters', {}).get('model', {}).get('driving_amp_ratio')
                print(f"  Driving_amp_ratio: {driving_amp_ratio}")
            except Exception as e:
                print(f"  Error reading node.json: {e}")
                driving_amp_ratio = None
            
            # Load data using qcat parser
            ds = load_xarray_h5(h5_file_path)
            
            # Handle multiple qubits if present
            if 'qubit' in ds.dims:
                qubit_data = repetition_data(ds, repetition_dim="qubit")
            else:
                qubit_data = [ds]
            
            # Process each qubit in the dataset
            for i, sq_data in enumerate(qubit_data):
                try:
                    qubit_name = sq_data["qubit"].values.item() if "qubit" in sq_data else f"Dataset_{i}"
                except:
                    qubit_name = f"Dataset_{i}"
                
                # Get driving_time and driving_frequency arrays
                driving_time = sq_data.coords["driving_time"].values
                driving_freq = sq_data.coords["driving_frequency"].values
                
                # Collect state_data arrays for averaging (same logic as parametric_drive_T1.ipynb cell 7)
                state_data_arrays = []
                
                for time in target_times:
                    # Find closest time in the data
                    time_idx = np.argmin(np.abs(driving_time - time))
                    actual_time = driving_time[time_idx]
                    
                    # Extract state data for this time, selecting index 2 from basis axis
                    state_data = sq_data["state"].isel(driving_time=time_idx, basis=2).values
                    state_data_arrays.append(state_data)
                
                # Calculate average state_data
                avg_state_data = np.mean(state_data_arrays, axis=0)
                # avg_state_data = sq_data["state"].mean(dim="driving_time").values
                # Find frequency with minimum avg_state_data
                min_idx = np.argmin(avg_state_data)
                min_freq = driving_freq[min_idx]
                min_value = avg_state_data[min_idx]
                
                # Extract full state_data time trace at minimum frequency, selecting index 2 from basis axis
                state_data_at_min_freq = sq_data["state"].isel(driving_frequency=min_idx, basis=2).values
                
                # Store results
                result = {
                    'folder': folder,
                    'qubit': qubit_name,
                    'min_freq_hz': min_freq,
                    'min_freq_ghz': min_freq / 1e9,
                    'min_avg_state_data': min_value,
                    'driving_amp_ratio': driving_amp_ratio,
                    'h5_file': h5_file_path,
                    'driving_time': driving_time.copy(),
                    'state_data_at_min_freq': state_data_at_min_freq.copy()
                }
                results.append(result)
                
        except Exception as e:
            print(f"  ERROR processing {folder}: {e}")
            continue
    
    # Summary table
    if results:
        print(f"\n{'='*60}")
        print("SUMMARY: Frequencies with Minimum avg_state_data")
        print(f"{'='*60}")
        print(f"{'Folder':<30} {'Qubit':<8} {'Min Freq (GHz)':<13} {'Min Value':<10} {'Amp Ratio':<10}")
        print("-" * 75)
        
        for result in results:
            folder_short = result['folder'][:28] + '..' if len(result['folder']) > 30 else result['folder']
            amp_ratio_str = f"{result['driving_amp_ratio']:.3f}" if result['driving_amp_ratio'] is not None else "N/A"
            print(f"{folder_short:<30} {result['qubit']:<8} {result['min_freq_ghz']:<13.6f} {result['min_avg_state_data']:<10.6f} {amp_ratio_str:<10}")
        
        # Statistics
        min_freqs = [r['min_freq_ghz'] for r in results]
        min_values = [r['min_avg_state_data'] for r in results]
        amp_ratios = [r['driving_amp_ratio'] for r in results if r['driving_amp_ratio'] is not None]
        
        print(f"\nSTATISTICS:")
        print(f"  Total datasets processed: {len(results)}")
        print(f"  Min frequency range: {min(min_freqs):.6f} - {max(min_freqs):.6f} GHz")
        print(f"  Mean min frequency: {np.mean(min_freqs):.6f} GHz")
        print(f"  Std min frequency: {np.std(min_freqs):.6f} GHz")
        print(f"  Min avg_state_data range: {min(min_values):.6f} - {max(min_values):.6f}")
        print(f"  Mean min avg_state_data: {np.mean(min_values):.6f}")
        
        if amp_ratios:
            print(f"  Driving amp ratio range: {min(amp_ratios):.3f} - {max(amp_ratios):.3f}")
            print(f"  Mean driving amp ratio: {np.mean(amp_ratios):.3f}")
            print(f"  Std driving amp ratio: {np.std(amp_ratios):.3f}")
        else:
            print(f"  No driving amp ratio data available")
        
    else:
        print("\nNo results obtained. Check if files are accessible and contain valid data.")
        
else:

    print("No folders with both required files found. Please run cell 4 first.")


print(f"\nAnalysis complete!")
# Out:
# Extracting data from verified folders...
# ============================================================
#
# Processing: #1508_LCH_qubit_parametric_drive_time_tomo_0_224304
#   Driving_amp_ratio: 0.75
#
# Processing: #1509_LCH_qubit_parametric_drive_time_tomo_1_225238
#   Driving_amp_ratio: 0.8
#
# Processing: #1510_LCH_qubit_parametric_drive_time_tomo_2_230213
#   Driving_amp_ratio: 0.85
#
# Processing: #1511_LCH_qubit_parametric_drive_time_tomo_3_231147
#   Driving_amp_ratio: 0.9
#
# Processing: #1512_LCH_qubit_parametric_drive_time_tomo_4_232122
#   Driving_amp_ratio: 0.95
#
# Processing: #1513_LCH_qubit_parametric_drive_time_tomo_5_233056
#   Driving_amp_ratio: 1.0
#
# Processing: #1514_LCH_qubit_parametric_drive_time_tomo_6_234031
#   Driving_amp_ratio: 1.05
#
# Processing: #1515_LCH_qubit_parametric_drive_time_tomo_7_235006
#   Driving_amp_ratio: 1.1
#
# Processing: #1516_LCH_qubit_parametric_drive_time_tomo_8_235940
#   Driving_amp_ratio: 1.15
#
# Processing: #1517_LCH_qubit_parametric_drive_time_tomo_9_000914
#   Driving_amp_ratio: 1.2
#
# Processing: #1518_LCH_qubit_parametric_drive_time_tomo_10_001849
#   Driving_amp_ratio: 1.25
#
# Processing: #1519_LCH_qubit_parametric_drive_time_tomo_11_002823
#   Driving_amp_ratio: 1.3
#
# Processing: #1520_LCH_qubit_parametric_drive_time_tomo_12_003758
#   Driving_amp_ratio: 1.35
#
# Processing: #1521_LCH_qubit_parametric_drive_time_tomo_13_004732
#   Driving_amp_ratio: 1.4
#
# Processing: #1522_LCH_qubit_parametric_drive_time_tomo_14_005707
#   Driving_amp_ratio: 1.45
#
# ============================================================
# SUMMARY: Frequencies with Minimum avg_state_data
# ============================================================
# Folder                         Qubit    Min Freq (GHz) Min Value  Amp Ratio
# ---------------------------------------------------------------------------
# #1508_LCH_qubit_parametric_d.. q1       0.292310      0.745455   0.750
# #1509_LCH_qubit_parametric_d.. q1       0.294450      0.729727   0.800
# #1510_LCH_qubit_parametric_d.. q1       0.296800      0.692545   0.850
# #1511_LCH_qubit_parametric_d.. q1       0.299380      0.651182   0.900
# #1512_LCH_qubit_parametric_d.. q1       0.302310      0.581182   0.950
# #1513_LCH_qubit_parametric_d.. q1       0.305590      0.502182   1.000
# #1514_LCH_qubit_parametric_d.. q1       0.308980      0.420636   1.050
# #1515_LCH_qubit_parametric_d.. q1       0.312180      0.347636   1.100
# #1516_LCH_qubit_parametric_d.. q1       0.315150      0.279636   1.150
# #1517_LCH_qubit_parametric_d.. q1       0.317950      0.243545   1.200
# #1518_LCH_qubit_parametric_d.. q1       0.320730      0.214727   1.250
# #1519_LCH_qubit_parametric_d.. q1       0.323550      0.190727   1.300
# #1520_LCH_qubit_parametric_d.. q1       0.326270      0.176000   1.350
# #1521_LCH_qubit_parametric_d.. q1       0.328770      0.172364   1.400
# #1522_LCH_qubit_parametric_d.. q1       0.330950      0.162727   1.450
#
# STATISTICS:
#   Total datasets processed: 15
#   Min frequency range: 0.292310 - 0.330950 GHz
#   Mean min frequency: 0.311691 GHz
#   Std min frequency: 0.012457 GHz
#   Min avg_state_data range: 0.162727 - 0.745455
#   Mean min avg_state_data: 0.407352
#   Driving amp ratio range: 0.750 - 1.450
#   Mean driving amp ratio: 1.100
#   Std driving amp ratio: 0.216
#
# Analysis complete!

# %%
# Collect all plotting data and save as xarray .h5 file
import xarray as xr
import os

if 'results' in locals() and results:
    print("Collecting all plotting data and saving as xarray .h5 file...")
    print("=" * 60)
    
    # Prepare data for both plotting functions
    valid_results = [r for r in results if r['driving_amp_ratio'] is not None and 'state_data_at_min_freq' in r]
    
    if valid_results:
        # Sort results by min frequency for consistent ordering
        valid_results.sort(key=lambda x: x['min_freq_ghz'])
        
        # Extract data for plotting 1: Min Frequency vs Driving_amp_ratio
        amp_ratios = []
        min_freqs_ghz = []
        folder_labels = []
        
        for result in valid_results:
            amp_ratios.append(result['driving_amp_ratio'])
            min_freqs_ghz.append(result['min_freq_ghz'])
            # Create short folder labels
            folder_short = result['folder'][:15] + '..' if len(result['folder']) > 15 else result['folder']
            folder_labels.append(f"{folder_short} ({result['qubit']})")
        
        # Extract data for plotting 2: 2D pcolormesh
        state_data_matrix = []
        detailed_labels = []
        
        for idx, result in enumerate(valid_results):
            # Use pre-stored state data
            state_data_matrix.append(result['state_data_at_min_freq'])
            
            # Create detailed label
            folder_short = result['folder'][:20] + '..' if len(result['folder']) > 22 else result['folder']
            label = f"{folder_short} ({result['min_freq_ghz']:.4f}GHz)"
            detailed_labels.append(label)
        
        # Use driving time from first result (should be same for all)
        X_time = valid_results[0]['driving_time']
        Y_freq = np.array(min_freqs_ghz)
        state_data_matrix = np.array(state_data_matrix)
        
        # Create comprehensive xarray Dataset
        ds = xr.Dataset(
            data_vars={
                'state_data_2d': (['frequency_idx', 'time'], state_data_matrix),
                'amp_ratios': (['frequency_idx'], amp_ratios),
                'min_freqs_ghz': (['frequency_idx'], min_freqs_ghz),
                'folder_labels': (['frequency_idx'], folder_labels),
                'detailed_labels': (['frequency_idx'], detailed_labels),
                'folder_names': (['frequency_idx'], [r['folder'] for r in valid_results]),
                'qubit_names': (['frequency_idx'], [r['qubit'] for r in valid_results])
            },
            coords={
                'frequency_idx': np.arange(len(valid_results)),
                'time': X_time,
                'frequency_ghz': (['frequency_idx'], Y_freq)
            },
            attrs={
                'description': 'Parametric drive T1 group analysis - plotting data',
                'time_units': 'ns',
                'frequency_units': 'GHz',
                'state_data_description': 'State data at minimum frequencies vs driving time',
                'n_files': len(valid_results),
                'creation_date': '2026-02-03'
            }
        )
        
        # Save to .h5 file in root_folder
        h5_output_path = os.path.join(root_folder, 'parametric_drive_T1_plotting_data.h5')
        ds.to_netcdf(h5_output_path)
        
        print(f"✅ Saved plotting data to: {h5_output_path}")
        print(f"\nDataset structure:")
        print(ds)
        print(f"\nDimensions:")
        print(f"  frequency_idx: {len(valid_results)} datasets")
        print(f"  time: {len(X_time)} points (range: {X_time.min():.1f} - {X_time.max():.1f} ns)")
        print(f"\nData variables:")
        print(f"  state_data_2d: {state_data_matrix.shape} - 2D state data matrix")
        print(f"  amp_ratios: {len(amp_ratios)} values (range: {min(amp_ratios):.3f} - {max(amp_ratios):.3f})")
        print(f"  min_freqs_ghz: {len(min_freqs_ghz)} values (range: {min(min_freqs_ghz):.6f} - {max(min_freqs_ghz):.6f} GHz)")
        
        # Store variables for backward compatibility (if other cells still need them)
        globals().update({
            'plotting_data_saved': True,
            'h5_plotting_file': h5_output_path
        })
        
    else:
        print("No valid results found for saving plotting data.")
else:
    print("No results data available. Please run cell 5 first to extract data.")
# Out:
# Collecting all plotting data and saving as xarray .h5 file...
# ============================================================
# ✅ Saved plotting data to: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/parametric_drive_T1_plotting_data.h5
#
# Dataset structure:
# <xarray.Dataset> Size: 26kB
# Dimensions:          (frequency_idx: 15, time: 150)
# Coordinates:
#   * frequency_idx    (frequency_idx) int64 120B 0 1 2 3 4 5 ... 9 10 11 12 13 14
#   * time             (time) int32 600B 20 60 100 140 180 ... 5860 5900 5940 5980
#     frequency_ghz    (frequency_idx) float64 120B 0.2923 0.2944 ... 0.3288 0.331
# Data variables:
#     state_data_2d    (frequency_idx, time) float64 18kB 0.825 0.814 ... 0.043
#     amp_ratios       (frequency_idx) float64 120B 0.75 0.8 0.85 ... 1.4 1.45
#     min_freqs_ghz    (frequency_idx) float64 120B 0.2923 0.2944 ... 0.3288 0.331
#     folder_labels    (frequency_idx) <U22 1kB '#1508_LCH_qubit.. (q1)' ... '#...
#     detailed_labels  (frequency_idx) <U34 2kB '#1508_LCH_qubit_para.. (0.2923...
#     folder_names     (frequency_idx) <U52 3kB '#1508_LCH_qubit_parametric_dri...
#     qubit_names      (frequency_idx) <U2 120B 'q1' 'q1' 'q1' ... 'q1' 'q1' 'q1'
# Attributes:
#     description:             Parametric drive T1 group analysis - plotting data
#     time_units:              ns
#     frequency_units:         GHz
#     state_data_description:  State data at minimum frequencies vs driving time
#     n_files:                 15
#     creation_date:           2026-02-03
#
# Dimensions:
#   frequency_idx: 15 datasets
#   time: 150 points (range: 20.0 - 5980.0 ns)
#
# Data variables:
#   state_data_2d: (15, 150) - 2D state data matrix
#   amp_ratios: 15 values (range: 0.750 - 1.450)
#   min_freqs_ghz: 15 values (range: 0.292310 - 0.330950 GHz)

# %%
# Plot Min Frequency as function of Driving_amp_ratio (from saved data)
import xarray as xr
import os

# Load plotting data from saved .h5 file
h5_plotting_file = os.path.join(root_folder, 'parametric_drive_T1_plotting_data.h5')

if os.path.exists(h5_plotting_file):
    print("Loading plotting data from saved .h5 file...")
    ds = xr.load_dataset(h5_plotting_file)
    
    # Extract data for plotting
    amp_ratios = ds['amp_ratios'].values
    min_freqs_ghz = ds['min_freqs_ghz'].values
    folder_labels = ds['folder_labels'].values
    
    print(f"Loaded {len(amp_ratios)} data points from {h5_plotting_file}")
    print("Creating plot: Min Frequency vs Driving Amplitude Ratio")
    
    if len(amp_ratios) > 0:
        # Create the plot
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(amp_ratios, min_freqs_ghz, s=80, alpha=0.7, c='blue', edgecolors='navy')
        
        # Formatting
        plt.xlabel('Driving Amplitude Ratio', fontsize=12, fontweight='bold')
        plt.ylabel('Min Frequency (GHz)', fontsize=12, fontweight='bold')
        plt.title('Minimum Frequency vs Driving Amplitude Ratio', fontsize=14, fontweight='bold')
        plt.grid(True, alpha=0.3)
        
        # Add statistics text
        stats_text = f'Points: {len(amp_ratios)}'
        plt.text(0.02, 0.98, stats_text, transform=plt.gca().transAxes, 
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
        
        plt.tight_layout()
        plt.show()
        
        # Print data summary
        print(f"\nData Summary:")
        print(f"  Number of data points: {len(amp_ratios)}")
        print(f"  Driving amp ratio range: {min(amp_ratios):.3f} - {max(amp_ratios):.3f}")
        print(f"  Min frequency range: {min(min_freqs_ghz):.6f} - {max(min_freqs_ghz):.6f} GHz")
        
        # Additional plot with annotations
        plt.figure(figsize=(14, 8))
        for i, (amp, freq, label) in enumerate(zip(amp_ratios, min_freqs_ghz, folder_labels)):
            plt.scatter(amp, freq, s=80, alpha=0.7, c='blue', edgecolors='navy')
            plt.annotate(label, (amp, freq), xytext=(5, 5), textcoords='offset points', 
                        fontsize=8, alpha=0.7)
        
        plt.xlabel('Driving Amplitude Ratio', fontsize=12, fontweight='bold')
        plt.ylabel('Min Frequency (GHz)', fontsize=12, fontweight='bold')
        plt.title('Minimum Frequency vs Driving Amplitude Ratio (with labels)', fontsize=14, fontweight='bold')
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
        
    else:
        print("No data points found for plotting.")
        
else:
    print(f"Plotting data file not found: {h5_plotting_file}")
    print("Please run cell 6 first to save the plotting data.")
# Out:
# Loading plotting data from saved .h5 file...
# Loaded 15 data points from /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/parametric_drive_T1_plotting_data.h5
# Creating plot: Min Frequency vs Driving Amplitude Ratio
# Data Summary:
#   Number of data points: 15
#   Driving amp ratio range: 0.750 - 1.450
#   Min frequency range: 0.292310 - 0.330950 GHz

# %%
# Plot 2D pcolormesh: state_data vs driving_time at min_freq for each file (from saved data)
import xarray as xr
import os

# Load plotting data from saved .h5 file
h5_plotting_file = os.path.join(root_folder, 'parametric_drive_T1_plotting_data.h5')

if os.path.exists(h5_plotting_file):
    print("Loading 2D plotting data from saved .h5 file...")
    ds = xr.load_dataset(h5_plotting_file)
    
    # Extract data for 2D plotting
    state_data_matrix = ds['state_data_2d'].values
    labels = ds['detailed_labels'].values
    min_freqs = ds['min_freqs_ghz'].values
    time_data_list = ds['time'].values
    
    print(f"Loaded 2D data: {state_data_matrix.shape} from {h5_plotting_file}")
    print(f"Using data from {len(labels)} files for 2D visualization...")
    
    for idx, (label, freq) in enumerate(zip(labels, min_freqs)):
        print(f"  File {idx+1}: {label}")
    
    print(f"\nMatrix shape: {state_data_matrix.shape} (files × time_points)")
        
    # Create 2D pcolormesh plot
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 12))
    
    # Plot 1: Ordered by min frequency
    Y_indices = np.arange(len(labels))
    X_time = time_data_list
    X_mesh, Y_mesh = np.meshgrid(X_time, Y_indices)
    
    im1 = ax1.pcolormesh(X_mesh, Y_mesh, state_data_matrix, cmap='viridis', shading='auto')
    ax1.set_xlabel('Driving Time (ns)', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Dataset Index (ordered by min freq)', fontsize=12, fontweight='bold')
    ax1.set_title('State Data vs Driving Time at Min Frequencies (Freq Ordered)', fontsize=14, fontweight='bold')
    
    # Set y-tick labels
    ax1.set_yticks(Y_indices)
    ax1.set_yticklabels([f"{i}: {f:.4f}GHz" for i, f in enumerate(min_freqs)], fontsize=8)
    
    # Add colorbar
    cbar1 = plt.colorbar(im1, ax=ax1)
    cbar1.set_label('State Data', fontsize=12, fontweight='bold')
    
    # Plot 2: Ordered by min frequency with frequency as Y-axis
    Y_freq = np.array(min_freqs)
    X_mesh_freq, Y_mesh_freq = np.meshgrid(X_time, Y_freq)
    
    im2 = ax2.pcolormesh(X_mesh_freq, Y_mesh_freq, state_data_matrix, cmap='viridis', shading='auto')
    ax2.set_xlabel('Driving Time (ns)', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Min Frequency (GHz)', fontsize=12, fontweight='bold')
    ax2.set_title('State Data vs Driving Time and Min Frequency', fontsize=14, fontweight='bold')
    
    # Add colorbar
    cbar2 = plt.colorbar(im2, ax=ax2)
    cbar2.set_label('State Data', fontsize=12, fontweight='bold')
    
    plt.tight_layout()
    plt.show()
    
    # Print summary
    print(f"\nPlot Summary:")
    print(f"  Files plotted: {len(state_data_matrix)}")
    print(f"  Time range: {X_time[0]:.1f} - {X_time[-1]:.1f} ns")
    print(f"  Min frequency range: {min(min_freqs):.6f} - {max(min_freqs):.6f} GHz")
    print(f"  State data range: {np.min(state_data_matrix):.6f} - {np.max(state_data_matrix):.6f}")
    
    # Individual time traces plot
    plt.figure(figsize=(14, 8))
    for i, (state_trace, label, freq) in enumerate(zip(state_data_matrix, labels, min_freqs)):
        plt.plot(X_time, state_trace, label=f"{freq:.4f}GHz", alpha=0.7, linewidth=2)
    
    plt.xlabel('Driving Time (ns)', fontsize=12, fontweight='bold')
    plt.ylabel('State Data', fontsize=12, fontweight='bold')
    plt.title('Individual Time Traces at Min Frequencies', fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.3)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
    plt.tight_layout()
    plt.show()
        
else:
    print(f"Plotting data file not found: {h5_plotting_file}")
    print("Please run cell 6 first to save the plotting data.")
# Out:
# Loading 2D plotting data from saved .h5 file...
# Loaded 2D data: (15, 150) from /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/parametric_drive_T1_plotting_data.h5
# Using data from 15 files for 2D visualization...
#   File 1: #1508_LCH_qubit_para.. (0.2923GHz)
#   File 2: #1509_LCH_qubit_para.. (0.2944GHz)
#   File 3: #1510_LCH_qubit_para.. (0.2968GHz)
#   File 4: #1511_LCH_qubit_para.. (0.2994GHz)
#   File 5: #1512_LCH_qubit_para.. (0.3023GHz)
#   File 6: #1513_LCH_qubit_para.. (0.3056GHz)
#   File 7: #1514_LCH_qubit_para.. (0.3090GHz)
#   File 8: #1515_LCH_qubit_para.. (0.3122GHz)
#   File 9: #1516_LCH_qubit_para.. (0.3151GHz)
#   File 10: #1517_LCH_qubit_para.. (0.3180GHz)
#   File 11: #1518_LCH_qubit_para.. (0.3207GHz)
#   File 12: #1519_LCH_qubit_para.. (0.3236GHz)
#   File 13: #1520_LCH_qubit_para.. (0.3263GHz)
#   File 14: #1521_LCH_qubit_para.. (0.3288GHz)
#   File 15: #1522_LCH_qubit_para.. (0.3310GHz)
#
# Matrix shape: (15, 150) (files × time_points)
# Plot Summary:
#   Files plotted: 15
#   Time range: 20.0 - 5980.0 ns
#   Min frequency range: 0.292310 - 0.330950 GHz
#   State data range: 0.034000 - 0.837000

# %%
# SVD and Hankel Matrix Analysis for each file - save plots to folders
from hankel_svd_analyzer import HankelSVDAnalyzer
import importlib
import hankel_svd_analyzer
importlib.reload(hankel_svd_analyzer)
from hankel_svd_analyzer import HankelSVDAnalyzer
import json

if 'results' in locals() and results:
    print("Performing SVD and Hankel Matrix analysis for each file...")
    print("=" * 60)
    
    # Prepare data for analysis using pre-stored data
    valid_results = [r for r in results if r['driving_amp_ratio'] is not None and 'state_data_at_min_freq' in r]
    
    if valid_results:
        print(f"Processing {len(valid_results)} files for SVD analysis...")
        
        for idx, result in enumerate(valid_results):
            try:
                print(f"\n=== Processing file {idx+1}/{len(valid_results)}: {result['folder']} ===")
                
                # Create output directory for this file
                output_dir = os.path.join(root_folder, result['folder'], 'svd_analysis')
                os.makedirs(output_dir, exist_ok=True)
                print(f"  Output directory: {output_dir}")
                
                # Extract data
                state_data = result['state_data_at_min_freq']
                driving_time = result['driving_time']
                min_freq_ghz = result['min_freq_ghz']
                folder_name = result['folder']
                qubit_name = result['qubit']
                
                print(f"  Min frequency: {min_freq_ghz:.6f} GHz")
                print(f"  Data points: {len(state_data)}")
                
                # Initialize the analyzer
                dt_ns = driving_time[1] - driving_time[0]  # Time step in nanoseconds
                analyzer = HankelSVDAnalyzer(dt_ns*1e-9)
                
                # Perform SVD analysis
                U, s, Vt = analyzer.analyze_signal(state_data)
                
                # Reconstruct signal using first few modes
                n_modes = min(5, len(s))
                reconstructed_signal = analyzer.reconstruct_signal(n_modes)
                
                # Get estimated n_components for vertical line annotations
                estimated_n_components = analyzer.estimate_n_components('energy', threshold=0.999)
                
                # Calculate x-axis limit based on 99% energy threshold
                cumulative_energy = np.cumsum(s**2) / np.sum(s**2)
                max_mode_99 = np.where(cumulative_energy < 0.995)[0]
                if len(max_mode_99) > 0:
                    x_limit_max = max_mode_99[-1] + 2  # +2 for better visualization
                else:
                    x_limit_max = min(10, len(s))  # fallback limit
                
                # Plot 1: SVD Reconstruction
                plt.figure(figsize=(10, 6))
                plt.plot(driving_time, state_data, 'b-', linewidth=2, label='Original')
                plt.plot(driving_time, reconstructed_signal, 'r--', linewidth=2, label=f'SVD Reconstruction ({n_modes} modes)')
                plt.xlabel('Driving Time (ns)')
                plt.ylabel('State')
                plt.title(f'SVD Reconstruction - {folder_name}\nQubit: {qubit_name} @ {min_freq_ghz:.6f} GHz')
                plt.legend()
                plt.grid(True, alpha=0.3)
                plt.tight_layout()
                plt.savefig(os.path.join(output_dir, '01_svd_reconstruction.png'), dpi=300, bbox_inches='tight')
                plt.close()
                
                # Plot 2: Singular Values
                plt.figure(figsize=(10, 6))
                plt.semilogy(s, 'bo-', markersize=4, linewidth=2)
                plt.axvline(x=estimated_n_components-1, color='red', linestyle='--', alpha=0.7, 
                           label=f'Estimated n_comp: {estimated_n_components}')
                plt.xlim(-0.5, x_limit_max - 0.5)
                plt.xlabel('Mode Number')
                plt.ylabel('Singular Value')
                plt.title(f'SVD Spectrum - {folder_name}\nQubit: {qubit_name} @ {min_freq_ghz:.6f} GHz')
                plt.legend()
                plt.grid(True, alpha=0.3)
                plt.tight_layout()
                plt.savefig(os.path.join(output_dir, '02_singular_values.png'), dpi=300, bbox_inches='tight')
                plt.close()
                
                # Plot 3: SVD Modes
                plt.figure(figsize=(10, 6))
                n_modes_plot = n_modes
                time_hankel = driving_time[:U.shape[0]]  # Time for Hankel matrix rows
                
                for mode in range(n_modes_plot):
                    plt.plot(time_hankel, U[:, mode], label=f'Mode {mode+1} (σ={s[mode]:.3f})', linewidth=1.5)
                
                plt.xlabel('Time (ns)')
                plt.ylabel('Amplitude')
                plt.title(f'SVD Modes - {folder_name}\nQubit: {qubit_name} @ {min_freq_ghz:.6f} GHz')
                plt.legend()
                plt.grid(True, alpha=0.3)
                plt.tight_layout()
                plt.savefig(os.path.join(output_dir, '03_svd_modes.png'), dpi=300, bbox_inches='tight')
                plt.close()
                
                # Plot 4: Singular Value Differences
                plt.figure(figsize=(10, 6))
                if len(s) > 1:
                    # Calculate log differences: log(s_i) - log(s_i+1)
                    log_s_diff = np.log(s[:-1]) - np.log(s[1:])
                    x_indices = np.arange(len(log_s_diff)) + 0.5
                    
                    plt.plot(x_indices, log_s_diff, 'go-', markersize=6, linewidth=2)
                    plt.axvline(x=estimated_n_components-0.5, color='red', linestyle='--', alpha=0.7, 
                               label=f'Estimated n_comp: {estimated_n_components}')
                    plt.xlim(0, x_limit_max - 0.5)
                    plt.xlabel('Singular Value Index + 0.5')
                    plt.ylabel('log(s_i) - log(s_{i+1})')
                    plt.title(f'Singular Value Log Differences - {folder_name}\nQubit: {qubit_name} @ {min_freq_ghz:.6f} GHz')
                    plt.grid(True, alpha=0.3)
                    
                    # Add annotation for interpretation
                    plt.axhline(y=0, color='black', linestyle='--', alpha=0.5, label='Zero difference')
                    plt.legend()
                else:
                    plt.text(0.5, 0.5, 'Not enough singular values\nfor difference calculation', 
                            transform=plt.gca().transAxes, ha='center', va='center', fontsize=12)
                    plt.xlabel('Singular Value Index + 0.5')
                    plt.ylabel('log(s_i) - log(s_{i+1})')
                    plt.title(f'Singular Value Log Differences - {folder_name}\nQubit: {qubit_name} @ {min_freq_ghz:.6f} GHz')
                    plt.grid(True, alpha=0.3)
                
                plt.tight_layout()
                plt.savefig(os.path.join(output_dir, '04_singular_value_differences.png'), dpi=300, bbox_inches='tight')
                plt.close()
                
                # Plot 5: Complementary Cumulative Energy
                plt.figure(figsize=(10, 6))
                if len(s) > 0:
                    # Calculate complementary cumulative energy: 1 - sum(s[:i]**2) / sum(s**2)
                    total_energy = np.sum(s**2)
                    i_values = np.arange(1, len(s) + 1)
                    complementary_energy = []
                    
                    for i in i_values:
                        cumulative_energy = np.sum(s[:i]**2) / total_energy
                        complementary_energy.append(1 - cumulative_energy)
                    
                    plt.semilogy(i_values, complementary_energy, 'mo-', markersize=6, linewidth=2)
                    plt.axvline(x=estimated_n_components, color='red', linestyle='--', alpha=0.7, 
                               label=f'Estimated n_comp: {estimated_n_components}')
                    plt.xlim(0.5, x_limit_max + 0.5)
                    plt.ylim(1e-3, 1)
                    plt.xlabel('Number of Components (i)')
                    plt.ylabel('1 - Σs²[:i] / Σs²')
                    plt.title(f'Complementary Cumulative Energy - {folder_name}\nQubit: {qubit_name} @ {min_freq_ghz:.6f} GHz')
                    plt.grid(True, alpha=0.3)
                    
                    # Add horizontal lines for reference
                    plt.axhline(y=0.1, color='gray', linestyle='--', alpha=0.5, label='10% remaining')
                    plt.axhline(y=0.01, color='orange', linestyle='--', alpha=0.5, label='1% remaining')
                    plt.legend()
                else:
                    plt.text(0.5, 0.5, 'No singular values available', 
                            transform=plt.gca().transAxes, ha='center', va='center', fontsize=12)
                    plt.xlabel('Number of Components (i)')
                    plt.ylabel('1 - Σs²[:i] / Σs²')
                    plt.title(f'Complementary Cumulative Energy - {folder_name}\nQubit: {qubit_name} @ {min_freq_ghz:.6f} GHz')
                    plt.grid(True, alpha=0.3)
                
                plt.tight_layout()
                plt.savefig(os.path.join(output_dir, '05_complementary_cumulative_energy.png'), dpi=300, bbox_inches='tight')
                plt.close()
                
                # === Extract Complex Poles ===
                # Sweep analysis with n_component_max = 10
                n_component_max = 10
                sweep_results = analyzer.sweep_components(min(n_component_max, len(s)))
                
                # Plot z poles as function of n_components
                if sweep_results:
                    # Collect z poles for plotting
                    n_components_list = []
                    z_real_list = []
                    z_imag_list = []
                    
                    for n_comp, poles in sweep_results.items():
                        for pole in poles:
                            n_components_list.append(n_comp)
                            z_real_list.append(pole['z_pole'].real)
                            z_imag_list.append(pole['z_pole'].imag)
                    
                    if n_components_list:  # Only plot if we have data
                        # Plot Real and Imaginary parts
                        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
                        
                        # Real part
                        ax1.scatter(n_components_list, z_real_list, alpha=0.2, s=50)
                        ax1.set_xlabel('Number of Components')
                        ax1.set_ylabel('Real(z)')
                        ax1.set_title(f'Real Part of z Poles - {folder_name}\nQubit: {qubit_name} @ {min_freq_ghz:.6f} GHz')
                        ax1.grid(True, alpha=0.3)
                        ax1.set_xticks(range(1, min(n_component_max, len(s))+1))
                        
                        # Imaginary part
                        ax2.scatter(n_components_list, z_imag_list, alpha=0.2, s=50)
                        ax2.set_xlabel('Number of Components')
                        ax2.set_ylabel('Imag(z)')
                        ax2.set_title(f'Imaginary Part of z Poles - {folder_name}\nQubit: {qubit_name} @ {min_freq_ghz:.6f} GHz')
                        ax2.grid(True, alpha=0.3)
                        ax2.set_xticks(range(1, min(n_component_max, len(s))+1))
                        
                        plt.tight_layout()
                        plt.savefig(os.path.join(output_dir, '06_complex_poles.png'), dpi=300, bbox_inches='tight')
                        plt.close()
                
                # Create analysis summary as JSON
                summary_data = {
                    'estimated_n_components': int(estimated_n_components),  # Convert numpy int to Python int
                    'sweep_results': {}
                }
                
                # Add pole information in JSON format
                if sweep_results:
                    for n_comp, poles in sweep_results.items():
                        summary_data['sweep_results'][str(n_comp)] = []
                        for pole in poles:
                            pole_data = {
                                'z_pole_real': float(pole["z_pole"].real),
                                'z_pole_imag': float(pole["z_pole"].imag), 
                                'time_constant': float(pole['time_constant']) if np.isfinite(pole['time_constant']) else None,
                                'freq_hz': float(pole['freq_hz'])
                            }
                            summary_data['sweep_results'][str(n_comp)].append(pole_data)
                
                # Save summary as JSON file
                with open(os.path.join(output_dir, 'analysis_summary.txt'), 'w') as f:
                    json.dump(summary_data, f, indent=2)
                
                print(f"  ✅ Analysis complete! Saved {6} plots + summary to {output_dir}")
                print(f"     Estimated n_components: {estimated_n_components}")
                
            except Exception as e:
                print(f"  ❌ ERROR analyzing {result['folder']}: {e}")
                continue
        
        print(f"\n{'='*60}")
        print(f"SVD/Hankel analysis complete for {len(valid_results)} files!")
        print("Generated files for each dataset:")
        print("  01_svd_reconstruction.png")
        print("  02_singular_values.png") 
        print("  03_svd_modes.png")
        print("  04_singular_value_differences.png")
        print("  05_complementary_cumulative_energy.png")
        print("  06_complex_poles.png")
        print("  analysis_summary.txt")
        
    else:
        print("No results with valid driving_amp_ratio and stored state data found for analysis.")
        
else:
    print("No results data available. Please run cell 5 first to extract data.")
# Out:
# Performing SVD and Hankel Matrix analysis for each file...
# ============================================================
# Processing 15 files for SVD analysis...
#
# === Processing file 1/15: #1508_LCH_qubit_parametric_drive_time_tomo_0_224304 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1508_LCH_qubit_parametric_drive_time_tomo_0_224304/svd_analysis
#   Min frequency: 0.292310 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1508_LCH_qubit_parametric_drive_time_tomo_0_224304/svd_analysis
#      Estimated n_components: 1
#
# === Processing file 2/15: #1509_LCH_qubit_parametric_drive_time_tomo_1_225238 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1509_LCH_qubit_parametric_drive_time_tomo_1_225238/svd_analysis
#   Min frequency: 0.294450 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1509_LCH_qubit_parametric_drive_time_tomo_1_225238/svd_analysis
#      Estimated n_components: 1
#
# === Processing file 3/15: #1510_LCH_qubit_parametric_drive_time_tomo_2_230213 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1510_LCH_qubit_parametric_drive_time_tomo_2_230213/svd_analysis
#   Min frequency: 0.296800 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1510_LCH_qubit_parametric_drive_time_tomo_2_230213/svd_analysis
#      Estimated n_components: 2
#
# === Processing file 4/15: #1511_LCH_qubit_parametric_drive_time_tomo_3_231147 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1511_LCH_qubit_parametric_drive_time_tomo_3_231147/svd_analysis
#   Min frequency: 0.299380 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1511_LCH_qubit_parametric_drive_time_tomo_3_231147/svd_analysis
#      Estimated n_components: 2
#
# === Processing file 5/15: #1512_LCH_qubit_parametric_drive_time_tomo_4_232122 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1512_LCH_qubit_parametric_drive_time_tomo_4_232122/svd_analysis
#   Min frequency: 0.302310 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1512_LCH_qubit_parametric_drive_time_tomo_4_232122/svd_analysis
#      Estimated n_components: 2
#
# === Processing file 6/15: #1513_LCH_qubit_parametric_drive_time_tomo_5_233056 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1513_LCH_qubit_parametric_drive_time_tomo_5_233056/svd_analysis
#   Min frequency: 0.305590 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1513_LCH_qubit_parametric_drive_time_tomo_5_233056/svd_analysis
#      Estimated n_components: 3
#
# === Processing file 7/15: #1514_LCH_qubit_parametric_drive_time_tomo_6_234031 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1514_LCH_qubit_parametric_drive_time_tomo_6_234031/svd_analysis
#   Min frequency: 0.308980 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1514_LCH_qubit_parametric_drive_time_tomo_6_234031/svd_analysis
#      Estimated n_components: 3
#
# === Processing file 8/15: #1515_LCH_qubit_parametric_drive_time_tomo_7_235006 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1515_LCH_qubit_parametric_drive_time_tomo_7_235006/svd_analysis
#   Min frequency: 0.312180 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1515_LCH_qubit_parametric_drive_time_tomo_7_235006/svd_analysis
#      Estimated n_components: 3
#
# === Processing file 9/15: #1516_LCH_qubit_parametric_drive_time_tomo_8_235940 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1516_LCH_qubit_parametric_drive_time_tomo_8_235940/svd_analysis
#   Min frequency: 0.315150 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1516_LCH_qubit_parametric_drive_time_tomo_8_235940/svd_analysis
#      Estimated n_components: 3
#
# === Processing file 10/15: #1517_LCH_qubit_parametric_drive_time_tomo_9_000914 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1517_LCH_qubit_parametric_drive_time_tomo_9_000914/svd_analysis
#   Min frequency: 0.317950 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1517_LCH_qubit_parametric_drive_time_tomo_9_000914/svd_analysis
#      Estimated n_components: 3
#
# === Processing file 11/15: #1518_LCH_qubit_parametric_drive_time_tomo_10_001849 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1518_LCH_qubit_parametric_drive_time_tomo_10_001849/svd_analysis
#   Min frequency: 0.320730 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1518_LCH_qubit_parametric_drive_time_tomo_10_001849/svd_analysis
#      Estimated n_components: 4
#
# === Processing file 12/15: #1519_LCH_qubit_parametric_drive_time_tomo_11_002823 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1519_LCH_qubit_parametric_drive_time_tomo_11_002823/svd_analysis
#   Min frequency: 0.323550 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1519_LCH_qubit_parametric_drive_time_tomo_11_002823/svd_analysis
#      Estimated n_components: 4
#
# === Processing file 13/15: #1520_LCH_qubit_parametric_drive_time_tomo_12_003758 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1520_LCH_qubit_parametric_drive_time_tomo_12_003758/svd_analysis
#   Min frequency: 0.326270 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1520_LCH_qubit_parametric_drive_time_tomo_12_003758/svd_analysis
#      Estimated n_components: 4
#
# === Processing file 14/15: #1521_LCH_qubit_parametric_drive_time_tomo_13_004732 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1521_LCH_qubit_parametric_drive_time_tomo_13_004732/svd_analysis
#   Min frequency: 0.328770 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1521_LCH_qubit_parametric_drive_time_tomo_13_004732/svd_analysis
#      Estimated n_components: 4
#
# === Processing file 15/15: #1522_LCH_qubit_parametric_drive_time_tomo_14_005707 ===
#   Output directory: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1522_LCH_qubit_parametric_drive_time_tomo_14_005707/svd_analysis
#   Min frequency: 0.330950 GHz
#   Data points: 150
#   ✅ Analysis complete! Saved 6 plots + summary to /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/#1522_LCH_qubit_parametric_drive_time_tomo_14_005707/svd_analysis
#      Estimated n_components: 4
#
# ============================================================
# SVD/Hankel analysis complete for 15 files!
# Generated files for each dataset:
#   01_svd_reconstruction.png
#   02_singular_values.png
#   03_svd_modes.png
#   04_singular_value_differences.png
#   05_complementary_cumulative_energy.png
#   06_complex_poles.png
#   analysis_summary.txt

# %%
# Collect pole analysis data and save as xarray .h5 file
import xarray as xr
import pandas as pd
import json
import os

if 'results' in locals() and results:
    print("Collecting pole analysis data and saving as xarray .h5 file...")
    print("=" * 60)
    
    # Prepare data for plotting
    valid_results = [r for r in results if r['driving_amp_ratio'] is not None]
    
    if valid_results:
        plot_data = []
        
        for result in valid_results:
            summary_file = os.path.join(root_folder, result['folder'], 'svd_analysis', 'analysis_summary.txt')
            
            if os.path.exists(summary_file):
                try:
                    with open(summary_file, 'r') as f:
                        summary_data = json.load(f)
                    
                    # Get estimated_n_components for this file
                    estimated_n_comp = summary_data.get('estimated_n_components')
                    
                    # Only extract pole data for n_components == estimated_n_components
                    if estimated_n_comp is not None and str(estimated_n_comp) in summary_data.get('sweep_results', {}):
                        poles = summary_data['sweep_results'][str(estimated_n_comp)]
                        
                        for pole_idx, pole in enumerate(poles):
                            if pole['time_constant'] is not None:  # Only valid time constants
                                plot_data.append({
                                    'folder': result['folder'],
                                    'amp_ratio': result['driving_amp_ratio'],
                                    'estimated_n_components': estimated_n_comp,
                                    'pole_idx': pole_idx,
                                    'time_constant': pole['time_constant'],
                                    'inv_time_constant': 1.0 / pole['time_constant'],
                                    'freq_hz': pole['freq_hz'],
                                    'z_pole_real': pole['z_pole_real'],
                                    'z_pole_imag': pole['z_pole_imag']
                                })
                        
                        print(f"  ✅ {result['folder']}: n_comp={estimated_n_comp}, {len(poles)} poles")
                    else:
                        print(f"  ⚠️  {result['folder']}: No valid estimated_n_components or pole data")
                        
                except Exception as e:
                    print(f"  ❌ ERROR reading {result['folder']}: {e}")
                    continue
            else:
                print(f"  ⚠️  Missing analysis file: {result['folder']}")
        
        if plot_data:
            print(f"\nCollected {len(plot_data)} pole data points from {len(set([d['folder'] for d in plot_data]))} files")
            
            # Convert to DataFrame for easier handling
            df = pd.DataFrame(plot_data)
            
            # Group by amp_ratio to handle multiple poles per amp_ratio
            grouped = df.groupby('amp_ratio')
            unique_amp_ratios = sorted(df['amp_ratio'].unique())
            max_poles = df.groupby('amp_ratio').size().max()
            
            # Initialize arrays with NaN
            inv_time_constants_array = np.full((len(unique_amp_ratios), max_poles), np.nan)
            freq_hz_array = np.full((len(unique_amp_ratios), max_poles), np.nan)
            time_constants_array = np.full((len(unique_amp_ratios), max_poles), np.nan)
            folder_names = []
            n_components_array = np.full(len(unique_amp_ratios), np.nan)
            
            # Fill arrays
            for i, amp_ratio in enumerate(unique_amp_ratios):
                group = grouped.get_group(amp_ratio)
                n_poles = len(group)
                
                # Fill data for this amp_ratio
                inv_time_constants_array[i, :n_poles] = group['inv_time_constant'].values
                freq_hz_array[i, :n_poles] = group['freq_hz'].values
                time_constants_array[i, :n_poles] = group['time_constant'].values
                
                # Get folder name and n_components (should be same for all poles with same amp_ratio)
                folder_names.append(group['folder'].iloc[0])
                n_components_array[i] = group['estimated_n_components'].iloc[0]
            
            # Create comprehensive xarray Dataset for pole analysis
            ds_poles = xr.Dataset(
                data_vars={
                    'inv_time_constant': (['amp_ratio', 'pole_index'], inv_time_constants_array),
                    'freq_hz': (['amp_ratio', 'pole_index'], freq_hz_array),
                    'time_constant': (['amp_ratio', 'pole_index'], time_constants_array),
                    'estimated_n_components': (['amp_ratio'], n_components_array),
                    'folder_name': (['amp_ratio'], folder_names),
                    'amp_ratios_for_plotting': (['data_point'], [d['amp_ratio'] for d in plot_data]),
                    'inv_time_constants_for_plotting': (['data_point'], [d['inv_time_constant'] for d in plot_data]),
                    'freq_hz_for_plotting': (['data_point'], [d['freq_hz'] for d in plot_data]),
                    'n_components_for_plotting': (['data_point'], [d['estimated_n_components'] for d in plot_data])
                },
                coords={
                    'amp_ratio': unique_amp_ratios,
                    'pole_index': np.arange(max_poles),
                    'data_point': np.arange(len(plot_data))
                },
                attrs={
                    'description': 'Pole analysis data from parametric drive T1 group analysis',
                    'inv_time_constant_units': 'Hz',
                    'freq_hz_units': 'Hz', 
                    'time_constant_units': 's',
                    'amp_ratio_description': 'Driving amplitude ratio',
                    'total_data_points': len(plot_data),
                    'unique_amp_ratios': len(unique_amp_ratios),
                    'max_poles_per_ratio': max_poles,
                    'creation_date': '2026-02-03'
                }
            )
            
            # Save to .h5 file
            h5_output_path = os.path.join(root_folder, 'pole_analysis_plotting_data.h5')
            ds_poles.to_netcdf(h5_output_path)
            
            print(f"✅ Saved pole analysis data to: {h5_output_path}")
            print(f"\nDataset structure:")
            print(ds_poles)
            print(f"\nDimensions:")
            print(f"  amp_ratio: {len(unique_amp_ratios)} unique ratios")
            print(f"  pole_index: {max_poles} max poles per ratio")
            print(f"  data_point: {len(plot_data)} total data points")
            print(f"\nData variables:")
            print(f"  Arrays for structured data (by amp_ratio)")
            print(f"  Arrays for direct plotting (flattened data points)")
            
            # Store variables for backward compatibility
            globals().update({
                'pole_data_saved': True,
                'h5_pole_file': h5_output_path
            })
            
        else:
            print("No valid pole data found for saving.")
            
    else:
        print("No results with valid driving_amp_ratio found.")
        
else:
    print("No results data available. Please run cell 5 first to extract data.")
# Out:
# Collecting pole analysis data and saving as xarray .h5 file...
# ============================================================
#   ✅ #1508_LCH_qubit_parametric_drive_time_tomo_0_224304: n_comp=1, 1 poles
#   ✅ #1509_LCH_qubit_parametric_drive_time_tomo_1_225238: n_comp=1, 1 poles
#   ✅ #1510_LCH_qubit_parametric_drive_time_tomo_2_230213: n_comp=2, 2 poles
#   ✅ #1511_LCH_qubit_parametric_drive_time_tomo_3_231147: n_comp=2, 2 poles
#   ✅ #1512_LCH_qubit_parametric_drive_time_tomo_4_232122: n_comp=2, 2 poles
#   ✅ #1513_LCH_qubit_parametric_drive_time_tomo_5_233056: n_comp=3, 2 poles
#   ✅ #1514_LCH_qubit_parametric_drive_time_tomo_6_234031: n_comp=3, 2 poles
#   ✅ #1515_LCH_qubit_parametric_drive_time_tomo_7_235006: n_comp=3, 2 poles
#   ✅ #1516_LCH_qubit_parametric_drive_time_tomo_8_235940: n_comp=3, 2 poles
#   ✅ #1517_LCH_qubit_parametric_drive_time_tomo_9_000914: n_comp=3, 2 poles
#   ✅ #1518_LCH_qubit_parametric_drive_time_tomo_10_001849: n_comp=4, 3 poles
#   ✅ #1519_LCH_qubit_parametric_drive_time_tomo_11_002823: n_comp=4, 3 poles
#   ✅ #1520_LCH_qubit_parametric_drive_time_tomo_12_003758: n_comp=4, 3 poles
#   ✅ #1521_LCH_qubit_parametric_drive_time_tomo_13_004732: n_comp=4, 3 poles
#   ✅ #1522_LCH_qubit_parametric_drive_time_tomo_14_005707: n_comp=4, 3 poles
#
# Collected 30 pole data points from 15 files
# ✅ Saved pole analysis data to: /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/pole_analysis_plotting_data.h5
#
# Dataset structure:
# <xarray.Dataset> Size: 6kB
# Dimensions:                          (amp_ratio: 15, pole_index: 3,
#                                       data_point: 30)
# Coordinates:
#   * amp_ratio                        (amp_ratio) float64 120B 0.75 0.8 ... 1.45
#   * pole_index                       (pole_index) int64 24B 0 1 2
#   * data_point                       (data_point) int64 240B 0 1 2 ... 27 28 29
# Data variables:
#     inv_time_constant                (amp_ratio, pole_index) float64 360B 1.2...
#     freq_hz                          (amp_ratio, pole_index) float64 360B 0.0...
#     time_constant                    (amp_ratio, pole_index) float64 360B 8.2...
#     estimated_n_components           (amp_ratio) float64 120B 1.0 1.0 ... 4.0
#     folder_name                      (amp_ratio) <U52 3kB '#1508_LCH_qubit_pa...
#     amp_ratios_for_plotting          (data_point) float64 240B 0.75 0.8 ... 1.45
#     inv_time_constants_for_plotting  (data_point) float64 240B 1.213e+05 ... ...
#     freq_hz_for_plotting             (data_point) float64 240B 0.0 0.0 ... 0.0
#     n_components_for_plotting        (data_point) int64 240B 1 1 2 2 ... 4 4 4 4
# Attributes:
#     description:              Pole analysis data from parametric drive T1 gro...
#     inv_time_constant_units:  Hz
#     freq_hz_units:            Hz
#     time_constant_units:      s
#     amp_ratio_description:    Driving amplitude ratio
#     total_data_points:        30
#     unique_amp_ratios:        15
#     max_poles_per_ratio:      3
#     creation_date:            2026-02-03
#
# Dimensions:
#   amp_ratio: 15 unique ratios
#   pole_index: 3 max poles per ratio
#   data_point: 30 total data points
#
# Data variables:
#   Arrays for structured data (by amp_ratio)
#   Arrays for direct plotting (flattened data points)

# %%
# Plot pole analysis data (1/time_constant and freq_hz) vs driving_amp_ratio (from saved data)
import xarray as xr
import os

# Load pole analysis data from saved .h5 file
h5_pole_file = os.path.join(root_folder, 'pole_analysis_plotting_data.h5')

if os.path.exists(h5_pole_file):
    print("Loading pole analysis data from saved .h5 file...")
    ds_poles = xr.load_dataset(h5_pole_file)
    
    # Extract flattened data for direct plotting
    amp_ratios = ds_poles['amp_ratios_for_plotting'].values
    inv_time_constants = [-val for val in ds_poles['inv_time_constants_for_plotting'].values]  # Negative for decay rates
    freq_hz_values = ds_poles['freq_hz_for_plotting'].values
    n_components_values = ds_poles['n_components_for_plotting'].values
    
    print(f"Loaded {len(amp_ratios)} pole data points from {h5_pole_file}")
    print(f"Data from {len(ds_poles['amp_ratio'])} unique amplitude ratios")
    print("Creating plots: Pole Analysis vs Driving Amplitude Ratio")
    
    if len(amp_ratios) > 0:
        # Create simplified plots
        fig, axes = plt.subplots(1, 2, figsize=(15, 8), sharey=True)
        
        # Plot 1: 1/time_constant vs amp_ratio (linear scale)
        scatter1 = axes[0].scatter(amp_ratios, inv_time_constants, 
                                 c=n_components_values, cmap='viridis', 
                                 alpha=0.7, s=50, edgecolors='black', linewidth=0.5)
        axes[0].set_xlabel('Driving Amplitude Ratio')
        axes[0].set_ylabel('Decay rate (Hz)')
        axes[0].set_title('Decay rate vs Driving Amplitude Ratio')
        axes[0].grid(True, alpha=0.3)
        
        # Add horizontal line at y = 1/(10/1e6)
        axes[0].axhline(y=-1/(10/1e6), color='red', linestyle='--', alpha=0.8, linewidth=2, label='qubit deay')
        axes[0].axhline(y=-1/(0.35/1e6), color='black', linestyle='--', alpha=0.8, linewidth=2, label='resonator decay')

        axes[0].legend()
        
        cbar1 = plt.colorbar(scatter1, ax=axes[0])
        cbar1.set_label('estimated_n_comp')
        
        # Plot 2: freq_hz vs amp_ratio (linear scale)
        scatter2 = axes[1].scatter(amp_ratios, freq_hz_values*2*np.pi, 
                                 c=n_components_values, cmap='viridis', 
                                 alpha=0.7, s=50, edgecolors='black', linewidth=0.5)
        axes[1].set_xlabel('Driving Amplitude Ratio')
        axes[1].set_ylabel('Oscillation Frequency (Hz)')
        axes[1].set_title('Pole Frequency vs Driving Amplitude Ratio')
        axes[1].grid(True, alpha=0.3)
        cbar2 = plt.colorbar(scatter2, ax=axes[1])
        cbar2.set_label('estimated_n_comp')
        
        plt.tight_layout()
        plt.show()
        
        # Summary statistics
        print(f"\n{'='*50}")
        print("POLE ANALYSIS SUMMARY")
        print(f"{'='*50}")
        print(f"Total pole data points: {len(amp_ratios)}")
        print(f"Unique amplitude ratios: {len(ds_poles['amp_ratio'])}")
        print(f"Amp ratio range: {min(amp_ratios):.3f} - {max(amp_ratios):.3f}")
        print(f"Decay rate range: {min(inv_time_constants):.2e} - {max(inv_time_constants):.2e} (Hz)")
        print(f"Frequency range: {min(freq_hz_values):.2e} - {max(freq_hz_values):.2e} Hz")
        print(f"estimated_n_components range: {min(n_components_values)} - {max(n_components_values)}")
        
    else:
        print("No pole data points found for plotting.")
        
else:
    print(f"Pole analysis data file not found: {h5_pole_file}")
    print("Please run cell 10 first to save the pole analysis data.")
# Out:
# Loading pole analysis data from saved .h5 file...
# Loaded 30 pole data points from /Users/jacky/Library/CloudStorage/SynologyDrive-LCH_AS/data/EP/Parametric_drive/QtoR/20260210_tomo/x180/pole_analysis_plotting_data.h5
# Data from 15 unique amplitude ratios
# Creating plots: Pole Analysis vs Driving Amplitude Ratio
# ==================================================
# POLE ANALYSIS SUMMARY
# ==================================================
# Total pole data points: 30
# Unique amplitude ratios: 15
# Amp ratio range: 0.750 - 1.450
# Decay rate range: -3.36e+06 - -8.23e+04 (Hz)
# Frequency range: 0.00e+00 - 1.03e+06 Hz
# estimated_n_components range: 1 - 4
