# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import os
import netCDF4
import h5netcdf
dataset = []
dataset.append(xr.open_dataset(r"D:\HW\Quela\QM\QM_data\5Q4C_20241016_2_AS1608\5Q4C_20241016_2_AS1608\T1+xy_amp_pic\20241114_010809_T1_stat_std\T1_stat.nc"))
dataset.append(xr.open_dataset(r"D:\HW\Quela\QM\QM_data\5Q4C_20241016_2_AS1608\5Q4C_20241016_2_AS1608\20241114_172837_xy_amp_cali_XX_with_180\xy_amp_cali_Y-Y_with_180.nc"))
dataset.append(xr.open_dataset(r"D:\HW\Quela\QM\QM_data\5Q4C_20241016_2_AS1608\5Q4C_20241016_2_AS1608\20241114_172956_xy_amp_cali_X-X_with_180\xy_amp_cali_Y-Y_with_180.nc"))
dataset.append(xr.open_dataset(r"D:\HW\Quela\QM\QM_data\5Q4C_20241016_2_AS1608\5Q4C_20241016_2_AS1608\20241114_173117_xy_amp_cali_YY_with_180\xy_amp_cali_Y-Y_with_180.nc"))
dataset.append(xr.open_dataset(r"D:\HW\Quela\QM\QM_data\5Q4C_20241016_2_AS1608\5Q4C_20241016_2_AS1608\20241114_173229_xy_amp_cali_Y-Y_with_180\xy_amp_cali_Y-Y_with_180.nc"))

time = (dataset[0].coords["time"].values)/1000

from qcat.visualization.qubit_relaxation import plot_qubit_relaxation
from qcat.analysis.qubit.relaxation import qubit_relaxation_fitting

fig, ax = plt.subplots()
fit_result = qubit_relaxation_fitting(time, dataset[0].data_vars['q3_ro'].values[0])
ax.set_ylabel(f"voltage (mV)")
ax.set_xlabel("Wait time (us)")
ax.plot( time, fit_result.best_fit, label="T1 fit")
ax.plot( time, dataset[0].data_vars['q3_ro'][0],"o", label="T1 data",markersize=1)
ax.plot( time, dataset[1].data_vars['q3_ro'][0], label="X X")
ax.plot( time, dataset[2].data_vars['q3_ro'][0], label="X -X")
ax.plot( time, dataset[3].data_vars['q3_ro'][0], label="Y Y")
ax.plot( time, dataset[4].data_vars['q3_ro'][0], label="Y -Y")
ax.legend()

fig2, ax2 = plt.subplots()
ax2.set_ylabel(f"voltage (mV)")
ax2.set_xlabel("Wait time (us)")
ax2.plot( time, dataset[0].data_vars['q3_ro'][1],"o", label="T1 data",markersize=1)
ax2.plot( time, dataset[1].data_vars['q3_ro'][1], label="X X")
ax2.plot( time, dataset[2].data_vars['q3_ro'][1], label="X -X")
ax2.plot( time, dataset[3].data_vars['q3_ro'][1], label="Y Y")
ax2.plot( time, dataset[4].data_vars['q3_ro'][1], label="Y -Y")
ax2.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import os
import netCDF4
import h5netcdf
dataset = []
dataset.append(xr.open_dataset(r"D:\HW\Quela\QM\QM_data\5Q4C_20241016_2_AS1608\5Q4C_20241016_2_AS1608\T1+xy_amp_pic\20241114_010809_T1_stat_std\T1_stat.nc"))
dataset.append(xr.open_dataset(r"D:\HW\Quela\QM\QM_data\5Q4C_20241016_2_AS1608\5Q4C_20241016_2_AS1608\T1+detune3MHz\20241115_112914_xy_amp_cali_XX_with_180_detune3Mhz\xy_amp_cali_XX_with_180.nc"))
dataset.append(xr.open_dataset(r"D:\HW\Quela\QM\QM_data\5Q4C_20241016_2_AS1608\5Q4C_20241016_2_AS1608\T1+detune3MHz\20241115_113141_xy_amp_cali_X-X_with_180_detune3MHz\xy_amp_cali_X-X_with_180.nc"))


time = (dataset[0].coords["time"].values)/1000

from qcat.visualization.qubit_relaxation import plot_qubit_relaxation
from qcat.analysis.qubit.relaxation import qubit_relaxation_fitting

fig, ax = plt.subplots()
fit_result = qubit_relaxation_fitting(time, dataset[0].data_vars['q3_ro'].values[0])
ax.set_ylabel(f"voltage (mV)")
ax.set_xlabel("Wait time (us)")
ax.plot( time, fit_result.best_fit, label="T1 fit")
ax.plot( time, dataset[0].data_vars['q3_ro'][0],"o", label="T1 data",markersize=1)
ax.plot( time, dataset[1].data_vars['q3_ro'][0], label="X X")
ax.plot( time, dataset[2].data_vars['q3_ro'][0], label="X -X")

ax.legend()

fig2, ax2 = plt.subplots()
ax2.set_ylabel(f"voltage (mV)")
ax2.set_xlabel("Wait time (us)")
ax2.plot( time, dataset[0].data_vars['q3_ro'][1],"o", label="T1 data",markersize=1)
ax2.plot( time, dataset[1].data_vars['q3_ro'][1], label="X X")
ax2.plot( time, dataset[2].data_vars['q3_ro'][1], label="X -X")

ax2.legend()
