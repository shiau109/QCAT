# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import os
from qcat.visualization.rabi_chavron import plot_rabi_chavron_analysis_result

dataset = xr.open_dataset(r'd:\Data\5Qv4_0822_8_ITRIMixer\collection\q1_xy_idle_Rabi_20240605_1801.nc')
dataset = dataset.transpose("mixer", "frequency", "time")


time = dataset.coords["time"].values*4
freq = dataset.coords["frequency"].values /1e3


# for ro_name, data in dataset.data_vars.items():
data = dataset.data_vars["q1_ro"]

ref_freq = (dataset.attrs["ref_xy_IF"] +dataset.attrs["ref_xy_LO"])/1e9
print( ref_freq )
print( data.values[0].shape )
iSWAP_freq =  plot_rabi_chavron_analysis_result( data.values[0], freq +ref_freq, time ) 

plt.show()
# Out:
# 4.169
# (50, 96)
