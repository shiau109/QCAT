# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Load and Format File

# %%
raw_data = np.load(r'D:\Data\DR2_5Q\1u_Q2Z1_crosstalk_ramsey_20240118_1419.npz', allow_pickle=True)# ["arr_0"].item()
other_info = {}
for k, v in raw_data.items():
    print(k, v.shape)
    if k in ["paras","setting"]:
        other_info[k]=v.item()

for k, v in other_info.items():
    print(k)

d_z_target_amp = other_info["paras"]["d_z_target_amp"]
d_z_crosstalk_amp = other_info["paras"]["d_z_crosstalk_amp"]

# Create a 2D numpy array (example data)
data = raw_data["q2_ro"][0]

print(data.shape, d_z_target_amp.shape, d_z_crosstalk_amp.shape)
# Out:
# q2_ro (2, 50, 51)
# setting ()
# paras ()
# setting
# paras
# (50, 51) (50,) (51,)

# %%
from qcat.zline_crosstalk.ramsey_2dfft import analysis_crosstalk_value

analysis_crosstalk_value(d_z_crosstalk_amp, d_z_target_amp, data.transpose())
# Out:
# AAA (51,) (50,) (51, 50)
# [[ 1.30871173e-04  1.91208470e-04  9.96255983e-05 ...  7.79759992e-05
#    7.42739733e-05 -7.46795427e-05]
#  [ 5.50273914e-05  2.26801514e-04  5.64531571e-06 ...  7.48296190e-05
#   -2.95209963e-05 -8.58976957e-05]
#  [ 1.86039853e-04  7.02373791e-05 -1.03725575e-04 ...  2.10691724e-05
#   -9.04047567e-05 -5.52401211e-05]
#  ...
#  [ 7.65153501e-05  1.12358659e-04  9.56999805e-05 ...  1.75206951e-04
#    9.92544662e-05  4.79921807e-05]
#  [ 1.02494631e-04  1.88343014e-04  1.53314203e-04 ...  6.52426403e-05
#    7.42378939e-05 -2.23214590e-06]
#  [ 9.41010673e-05  1.50295544e-04  1.00422941e-04 ...  9.35587209e-05
#    7.02721175e-05 -1.58093762e-05]] (51, 50)
# length: 51, delta:0.00019999999999999966
# length: 50, delta:1.9999999999999944e-05
# Maximum value: 0.10594488387809586
# f_z_target: -294.117647058824
# f_z_crosstalk: -6000.000000000017
# k space: 20.400000000000027
# crosstalk: -0.04901960784313719
# (-0.04901960784313719,
#  [array([-2450.98039216, -2352.94117647, -2254.90196078, -2156.8627451 ,
#          -2058.82352941, -1960.78431373, -1862.74509804, -1764.70588235,
#          -1666.66666667, -1568.62745098, -1470.58823529, -1372.54901961,
#          -1274.50980392, -1176.47058824, -1078.43137255,  -980.39215686,
#           -882.35294118,  -784.31372549,  -686.2745098 ,  -588.23529412,
#           -490.19607843,  -392.15686275,  -294.11764706,  -196.07843137,
#            -98.03921569,     0.        ,    98.03921569,   196.07843137,
#            294.11764706,   392.15686275,   490.19607843,   588.23529412,
#            686.2745098 ,   784.31372549,   882.35294118,   980.39215686,
#           1078.43137255,  1176.47058824,  1274.50980392,  1372.54901961,
#           1470.58823529,  1568.62745098,  1666.66666667,  1764.70588235,
#           1862.74509804,  1960.78431373,  2058.82352941,  2156.8627451 ,
#           2254.90196078,  2352.94117647,  2450.98039216]),
#   array([-25000., -24000., -23000., -22000., -21000., -20000., -19000.,
#          -18000., -17000., -16000., -15000., -14000., -13000., -12000.,
#          -11000., -10000.,  -9000.,  -8000.,  -7000.,  -6000.,  -5000.,
#           -4000.,  -3000.,  -2000.,  -1000.,      0.,   1000.,   2000.,
#            3000.,   4000.,   5000.,   6000.,   7000.,   8000.,   9000.,
#           10000.,  11000.,  12000.,  13000.,  14000.,  15000.,  16000.,
#           17000.,  18000.,  19000.,  20000.,  21000.,  22000.,  23000.,
#           24000.])],
#  array([[0.00094111, 0.00328612, 0.00072629, ..., 0.00157585, 0.00159721,
#          0.00203026],
#         [0.00090567, 0.00014001, 0.00162371, ..., 0.00212425, 0.00320597,
#          0.00124814],
#         [0.00304376, 0.00060759, 0.00185743, ..., 0.00085305, 0.00172218,
#          0.00153054],
#         ...,
#         [0.00304376, 0.00153054, 0.00172218, ..., 0.00362544, 0.00185743,
#          0.00060759],
#         [0.00090567, 0.00124814, 0.00320597, ..., 0.00064876, 0.00162371,
#          0.00014001],
#         [0.00094111, 0.00203026, 0.00159721, ..., 0.00131127, 0.00072629,
#          0.00328612]]))

# %%
from qcat.visualization.zline_crosstalk import plot_analysis
plot_analysis(d_z_crosstalk_amp, d_z_target_amp, data.transpose())

plt.show()
# Out:
# AAA (51,) (50,) (51, 50)
# [[ 1.30871173e-04  1.91208470e-04  9.96255983e-05 ...  7.79759992e-05
#    7.42739733e-05 -7.46795427e-05]
#  [ 5.50273914e-05  2.26801514e-04  5.64531571e-06 ...  7.48296190e-05
#   -2.95209963e-05 -8.58976957e-05]
#  [ 1.86039853e-04  7.02373791e-05 -1.03725575e-04 ...  2.10691724e-05
#   -9.04047567e-05 -5.52401211e-05]
#  ...
#  [ 7.65153501e-05  1.12358659e-04  9.56999805e-05 ...  1.75206951e-04
#    9.92544662e-05  4.79921807e-05]
#  [ 1.02494631e-04  1.88343014e-04  1.53314203e-04 ...  6.52426403e-05
#    7.42378939e-05 -2.23214590e-06]
#  [ 9.41010673e-05  1.50295544e-04  1.00422941e-04 ...  9.35587209e-05
#    7.02721175e-05 -1.58093762e-05]] (51, 50)
# length: 51, delta:0.00019999999999999966
# length: 50, delta:1.9999999999999944e-05
# Maximum value: 0.10594488387809586
# f_z_target: -294.117647058824
# f_z_crosstalk: -6000.000000000017
# k space: 20.400000000000027
# crosstalk: -0.04901960784313719
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 from qcat.visualization.zline_crosstalk import plot_analysis
# ----> 2 plot_analysis(d_z_crosstalk_amp, d_z_target_amp, data.transpose())
#       4 plt.show()
#
# File c:\users\shiau\qcat\src\qcat\visualization\zline_crosstalk.py:16, in plot_analysis(z1, z2, data)
#      13 fig.set_size_inches(10, 5)
#      15 crosstalk, freq_axes, mag = analysis_crosstalk_value( z1, z2, data )
# ---> 16 _plot_rawdata( z1, z2, data, crosstalk, ax[0] )
#      18 _plot_2Dfft( freq_axes[0], freq_axes[1], mag, ax[1] )
#
# File c:\users\shiau\qcat\src\qcat\visualization\zline_crosstalk.py:26, in _plot_rawdata(x, y, z, slope, ax)
#      21 def _plot_rawdata( x, y, z, slope, ax=None ):
#      22     """
#      23     x is crosstalk voltage (other)\n
#      24     y is compensation voltage (self)
#      25     """
# ---> 26     ax.pcolormesh(x, y, z, cmap='gray')
#      27     ax.plot([x[0],x[-1]],[ x[0]*slope, x[-1]*slope ],color="r",linewidth=5)
#      28     ax.set_title('Original Image')
#
# File c:\Users\shiau\.conda\envs\PYQUM-server-offline\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File c:\Users\shiau\.conda\envs\PYQUM-server-offline\lib\site-packages\matplotlib\axes\_axes.py:6131, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6128 shading = shading.lower()
#    6129 kwargs.setdefault('edgecolors', 'none')
# -> 6131 X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6132                                     shading=shading, kwargs=kwargs)
#    6133 coords = np.stack([X, Y], axis=-1)
#    6134 # convert to one dimensional array
#
# File c:\Users\shiau\.conda\envs\PYQUM-server-offline\lib\site-packages\matplotlib\axes\_axes.py:5659, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    5657 if shading == 'flat':
#    5658     if (Nx, Ny) != (ncols + 1, nrows + 1):
# -> 5659         raise TypeError('Dimensions of C %s are incompatible with'
#    5660                         ' X (%d) and/or Y (%d); see help(%s)' % (
#    5661                             C.shape, Nx, Ny, funcname))
#    5662 else:    # ['nearest', 'gouraud']:
#    5663     if (Nx, Ny) != (ncols, nrows):
#
# TypeError: Dimensions of C (51, 50) are incompatible with X (51) and/or Y (50); see help(pcolormesh)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
